# %%
import pandas as pd

# %%
path = '../data/interim/'

# %%
df = pd.read_pickle(path+'data_analyst.pkl')

# %%
f = pd.read_pickle(path+'data_scientist.pkl')

# %%
f
# Out:
#                                               job_title  \
# 0                                 Senior Data Scientist
# 1                     Data Scientist, Product Analytics
# 2                                  Data Science Manager
# 3                                          Data Analyst
# 4                                Director, Data Science
# ...                                                 ...
# 3904                                  AWS Data Engineer
# 3905                              Data Analyst â Junior
# 3906                   Security Analytics Data Engineer
# 3907                   Security Analytics Data Engineer
# 3908  Patient Safety Physician or Safety Scientist -...
#
#                                         job_description  rating  \
# 0     ABOUT HOPPER\n\nAt Hopper, we’re on a mission ...     3.5
# 1     At Noom, we use scientifically proven methods ...     4.5
# 2     Decode_M\n\nhttps://www.decode-m.com/\n\nData ...    -1.0
# ...

# %%
df
# Out:
#                                               job_title  \
# 0     Data Analyst, Center on Immigration and Justic...
# 1                                  Quality Data Analyst
# 2     Senior Data Analyst, Insights & Analytics Team...
# 3                                          Data Analyst
# 4                                Reporting Data Analyst
# ...                                                 ...
# 2247  RQS - IHHA - 201900004460 -1q Data Security An...
# 2248              Senior Data Analyst (Corporate Audit)
# 2249  Technical Business Analyst (SQL, Data analytic...
# 2250                Data Analyst 3, Customer Experience
# 2251                        Senior Quality Data Analyst
#
#                                         job_description  rating  \
# 0     Are you eager to roll up your sleeves and harn...     3.2
# 1     Overview\n\nProvides analytical and technical ...     3.8
# 2     We’re looking for a Senior Data Analyst who ha...     3.4
# ...

# %%
fr = pd.concat([df,f])

# %%
fr
# Out:
#                                               job_title  \
# 0     Data Analyst, Center on Immigration and Justic...
# 1                                  Quality Data Analyst
# 2     Senior Data Analyst, Insights & Analytics Team...
# 3                                          Data Analyst
# 4                                Reporting Data Analyst
# ...                                                 ...
# 3904                                  AWS Data Engineer
# 3905                              Data Analyst â Junior
# 3906                   Security Analytics Data Engineer
# 3907                   Security Analytics Data Engineer
# 3908  Patient Safety Physician or Safety Scientist -...
#
#                                         job_description  rating  \
# 0     Are you eager to roll up your sleeves and harn...     3.2
# 1     Overview\n\nProvides analytical and technical ...     3.8
# 2     We’re looking for a Senior Data Analyst who ha...     3.4
# ...

# %%
fr.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 6140 entries, 0 to 3908
# Data columns (total 18 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   job_title          6140 non-null   object
#  1   job_description    6140 non-null   object
#  2   rating             6140 non-null   float64
#  3   company_name       6139 non-null   object
#  4   headquarters       6140 non-null   object
#  5   size               6140 non-null   object
#  6   founded            6140 non-null   int64
#  7   type_of_ownership  6140 non-null   object
#  8   industry           6140 non-null   object
#  9   sector             6140 non-null   object
#  10  revenue            6140 non-null   object
#  11  competitors        6140 non-null   object
#  12  easy_apply         6140 non-null   object
#  13  low_salary         6140 non-null   int64
#  14  high_salary        6140 non-null   int64
#  15  mid_salary         6140 non-null   float64
# ...

# %%
fr.duplicated().sum()
# Out:
# 1

# %%
fr = fr.drop_duplicates()

# %%
len(fr)
# Out:
# 6139

# %%
fr['job_description'].nunique()
# Out:
# 5293

# %%
fr.columns
# Out:
# Index(['job_title', 'job_description', 'rating', 'company_name',
#        'headquarters', 'size', 'founded', 'type_of_ownership', 'industry',
#        'sector', 'revenue', 'competitors', 'easy_apply', 'low_salary',
#        'high_salary', 'mid_salary', 'city', 'state'],
#       dtype='object')

# %% [markdown]
# Not all job descriptions are unique but that may be ok since there are no rows which are completely duplicated

# %%
fr = fr.reset_index(drop=True)

# %%
fr.to_pickle('../data/interim/combined.pkl')
